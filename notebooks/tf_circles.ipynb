# %% [markdown]
# # Circles (tensorflow)

# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from dOD.tf_model.model import UNet
from dOD.tf_model.datasets import circles
from dOD.tf_model.trainer import Trainer
from dOD.tf_model.layers import crop_image_labels_to_shape

# %%
circle_model = UNet(input_shape=(200, 200, 1), kernel_shape=(3, 3),
                    root_feature=16, depth=3, drop_rate=0.2, num_classes=circles.CLASSES)
circle_model.build_net()
circle_model.compile(optimizer='rmsprop')
circle_model.describle()
# Out:
# -------- input shape: (None, 200, 200, 1)
#     > layer 0 shape: (None, 200, 200, 16)
#     > layer 1 shape: (None, 200, 200, 16)
#     downstream layer 1 shape: (None, 200, 200, 16)
#         > layer 0 shape: (None, 100, 100, 32)
#         > layer 1 shape: (None, 100, 100, 32)
#         downstream layer 2 shape: (None, 100, 100, 32)
#             > layer 0 shape: (None, 50, 50, 64)
#             > layer 1 shape: (None, 50, 50, 64)
#             bottom layer 3 shape: (None, 50, 50, 64)
#         > layer 0 shape: (None, 100, 100, 32)
#         > layer 1 shape: (None, 100, 100, 32)
#         upstream layer 2 shape: (None, 100, 100, 32)
#     > layer 0 shape: (None, 200, 200, 16)
#     > layer 1 shape: (None, 200, 200, 16)
#     upstream layer 1 shape: (None, 200, 200, 16)
# -------- output shape: (None, 200, 200, 2)

# %%
train_ds, validation_ds, test_ds = circles.load_data(1000, nx=200, ny=200, splits=(0.7, 0.2, 0.1))

# %%
trainer = Trainer(save_ckpt=False)

# %%
history = trainer.fit(circle_model.net, train_ds,
                      validation_dataset=validation_ds, epochs=25, batch_size=32)
# Out:
# Epoch 1/25
# 22/22 [==============================] - 8s 355ms/step - loss: 0.2814 - binary_crossentropy: 0.2814 - binary_accuracy: 0.9609 - val_loss: 0.2200 - val_binary_crossentropy: 0.2200 - val_binary_accuracy: 0.9701
# Epoch 2/25
# 22/22 [==============================] - 7s 307ms/step - loss: 0.1678 - binary_crossentropy: 0.1678 - binary_accuracy: 0.9699 - val_loss: 0.1379 - val_binary_crossentropy: 0.1379 - val_binary_accuracy: 0.9702
# Epoch 3/25
# 22/22 [==============================] - 7s 310ms/step - loss: 0.0992 - binary_crossentropy: 0.0992 - binary_accuracy: 0.9787 - val_loss: 0.0521 - val_binary_crossentropy: 0.0521 - val_binary_accuracy: 0.9863
# Epoch 4/25
# 22/22 [==============================] - 7s 307ms/step - loss: 0.0552 - binary_crossentropy: 0.0552 - binary_accuracy: 0.9877 - val_loss: 0.0409 - val_binary_crossentropy: 0.0409 - val_binary_accuracy: 0.9887
# Epoch 5/25
# 22/22 [==============================] - 7s 310ms/step - loss: 0.0453 - binary_crossentropy: 0.0453 - binary_accuracy: 0.9898 - val_loss: 0.0344 - val_binary_crossentropy: 0.0344 - val_binary_accuracy: 0.9901
# Epoch 6/25
# 22/22 [==============================] - 7s 312ms/step - loss: 0.0427 - binary_crossentropy: 0.0427 - binary_accuracy: 0.9897 - val_loss: 0.0317 - val_binary_crossentropy: 0.0317 - val_binary_accuracy: 0.9913
# Epoch 7/25
# 22/22 [==============================] - 7s 320ms/step - loss: 0.0330 - binary_crossentropy: 0.0330 - binary_accuracy: 0.9922 - val_loss: 0.0303 - val_binary_crossentropy: 0.0303 - val_binary_accuracy: 0.9918
# Epoch 8/25
# 22/22 [==============================] - 7s 300ms/step - loss: 0.0280 - binary_crossentropy: 0.0280 - binary_accuracy: 0.9930 - val_loss: 0.0287 - val_binary_crossentropy: 0.0287 - val_binary_accuracy: 0.9922
# Epoch 9/25
# 22/22 [==============================] - 7s 314ms/step - loss: 0.0366 - binary_crossentropy: 0.0366 - binary_accuracy: 0.9912 - val_loss: 0.0276 - val_binary_crossentropy: 0.0276 - val_binary_accuracy: 0.9929
# Epoch 10/25
# 22/22 [==============================] - 7s 314ms/step - loss: 0.0248 - binary_crossentropy: 0.0248 - binary_accuracy: 0.9939 - val_loss: 0.0267 - val_binary_crossentropy: 0.0267 - val_binary_accuracy: 0.9924
# Epoch 11/25
# 22/22 [==============================] - 7s 315ms/step - loss: 0.0266 - binary_crossentropy: 0.0266 - binary_accuracy: 0.9938 - val_loss: 0.0271 - val_binary_crossentropy: 0.0271 - val_binary_accuracy: 0.9926
# Epoch 12/25
# 22/22 [==============================] - 7s 312ms/step - loss: 0.0246 - binary_crossentropy: 0.0246 - binary_accuracy: 0.9942 - val_loss: 0.0275 - val_binary_crossentropy: 0.0275 - val_binary_accuracy: 0.9923
# Epoch 13/25
# 22/22 [==============================] - 7s 318ms/step - loss: 0.0229 - binary_crossentropy: 0.0229 - binary_accuracy: 0.9944 - val_loss: 0.0263 - val_binary_crossentropy: 0.0263 - val_binary_accuracy: 0.9925
# Epoch 14/25
# 22/22 [==============================] - 7s 319ms/step - loss: 0.0222 - binary_crossentropy: 0.0222 - binary_accuracy: 0.9947 - val_loss: 0.0188 - val_binary_crossentropy: 0.0188 - val_binary_accuracy: 0.9956
# Epoch 15/25
# 22/22 [==============================] - 7s 317ms/step - loss: 0.0338 - binary_crossentropy: 0.0338 - binary_accuracy: 0.9903 - val_loss: 0.0226 - val_binary_crossentropy: 0.0226 - val_binary_accuracy: 0.9945
# Epoch 16/25
# 22/22 [==============================] - 7s 317ms/step - loss: 0.0201 - binary_crossentropy: 0.0201 - binary_accuracy: 0.9951 - val_loss: 0.0206 - val_binary_crossentropy: 0.0206 - val_binary_accuracy: 0.9943
# Epoch 17/25
# 22/22 [==============================] - 7s 315ms/step - loss: 0.0212 - binary_crossentropy: 0.0212 - binary_accuracy: 0.9951 - val_loss: 0.0214 - val_binary_crossentropy: 0.0214 - val_binary_accuracy: 0.9940
# Epoch 18/25
# 22/22 [==============================] - 6s 279ms/step - loss: 0.0209 - binary_crossentropy: 0.0209 - binary_accuracy: 0.9950 - val_loss: 0.0210 - val_binary_crossentropy: 0.0210 - val_binary_accuracy: 0.9945
# Epoch 19/25
# 22/22 [==============================] - 6s 280ms/step - loss: 0.0209 - binary_crossentropy: 0.0209 - binary_accuracy: 0.9949 - val_loss: 0.0193 - val_binary_crossentropy: 0.0193 - val_binary_accuracy: 0.9950
# Epoch 20/25
# 22/22 [==============================] - 6s 291ms/step - loss: 0.0196 - binary_crossentropy: 0.0196 - binary_accuracy: 0.9953 - val_loss: 0.0199 - val_binary_crossentropy: 0.0199 - val_binary_accuracy: 0.9945
# Epoch 21/25
# 22/22 [==============================] - 6s 287ms/step - loss: 0.0190 - binary_crossentropy: 0.0190 - binary_accuracy: 0.9955 - val_loss: 0.0180 - val_binary_crossentropy: 0.0180 - val_binary_accuracy: 0.9951
# Epoch 22/25
# 22/22 [==============================] - 6s 280ms/step - loss: 0.0188 - binary_crossentropy: 0.0188 - binary_accuracy: 0.9955 - val_loss: 0.0185 - val_binary_crossentropy: 0.0185 - val_binary_accuracy: 0.9949
# Epoch 23/25
# 22/22 [==============================] - 6s 282ms/step - loss: 0.0196 - binary_crossentropy: 0.0196 - binary_accuracy: 0.9953 - val_loss: 0.0171 - val_binary_crossentropy: 0.0171 - val_binary_accuracy: 0.9960
# Epoch 24/25
# 22/22 [==============================] - 6s 288ms/step - loss: 0.0174 - binary_crossentropy: 0.0174 - binary_accuracy: 0.9958 - val_loss: 0.0170 - val_binary_crossentropy: 0.0170 - val_binary_accuracy: 0.9955
# Epoch 25/25
# 22/22 [==============================] - 6s 277ms/step - loss: 0.0196 - binary_crossentropy: 0.0196 - binary_accuracy: 0.9952 - val_loss: 0.0163 - val_binary_crossentropy: 0.0163 - val_binary_accuracy: 0.9962

# %%
prediction = circle_model.net.predict(test_ds.batch(batch_size=5))

# %%
N = 5
fig, ax = plt.subplots(3, N, sharex=True, sharey=True,
                       figsize=(N * 3, 9), gridspec_kw={'wspace': 0.01, 'hspace': 0.015})
dataset = test_ds.map(crop_image_labels_to_shape(prediction.shape[1:]) )

for i, (img, label) in enumerate(dataset.take(N)):
    ax[0][i].imshow(tf.keras.preprocessing.image.array_to_img(img))
    ax[1][i].imshow(np.argmax(label, axis=-1), cmap=plt.cm.gray)
    ax[2][i].imshow(np.argmax(prediction[i, ...], axis=-1), cmap=plt.cm.gray)
for i, x in enumerate(['image', 'mask', 'prediction']):
    ax[i][0].set_ylabel(x);

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure()
plt.plot(range(25), train_loss, 'r--', label='training loss')
plt.plot(range(25), val_loss, 'bo', label='validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
