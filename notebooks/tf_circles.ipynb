# %% [markdown]
# # Circles (tensorflow)

# %% [markdown]
# > !pip install git+https://github.com/phylsix/dOD.git

# %%
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from dOD.tf_model.model import UNet
from dOD.tf_model.datasets import circles
from dOD.tf_model.trainer import Trainer
from dOD.tf_model.layers import crop_image_labels_to_shape

# %%
circle_model = UNet(input_shape=(200, 200, 1), kernel_shape=(3, 3),
                    root_feature=16, depth=3, num_classes=circles.CLASSES)
circle_model.build_net()
circle_model.compile(optimizer='rmsprop', loss=tf.keras.losses.BinaryCrossentropy())
circle_model.describle()
# Out:
# -------- input shape: (None, 200, 200, 1)
#     > layer 0 shape: (None, 200, 200, 16)
#     > layer 2 shape: (None, 200, 200, 16)
#     downstream layer 1 shape: (None, 200, 200, 16)
#         > layer 0 shape: (None, 100, 100, 32)
#         > layer 3 shape: (None, 100, 100, 32)
#         downstream layer 2 shape: (None, 100, 100, 32)
#             > layer 0 shape: (None, 50, 50, 64)
#             > layer 3 shape: (None, 50, 50, 64)
#             bottom layer 3 shape: (None, 50, 50, 64)
#         > layer 0 shape: (None, 100, 100, 32)
#         > layer 3 shape: (None, 100, 100, 32)
#         upstream layer 2 shape: (None, 100, 100, 32)
#     > layer 0 shape: (None, 200, 200, 16)
#     > layer 3 shape: (None, 200, 200, 16)
#     upstream layer 1 shape: (None, 200, 200, 16)
# -------- output shape: (None, 200, 200, 2)

# %%
train_ds, validation_ds, test_ds = circles.load_data(1000, nx=200, ny=200, splits=(0.7, 0.2, 0.1))

# %%
trainer = Trainer(save_ckpt=False)

# %%
history = trainer.fit(circle_model.net, train_ds,
                      validation_dataset=validation_ds, epochs=25, batch_size=32)
# Out:
# Epoch 1/25
#  2/22 [=>............................] - ETA: 3s - loss: 0.6323 - binary_crossentropy: 0.6323 - binary_accuracy: 0.7226WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1232s vs `on_train_batch_end` time: 0.1986s). Check your callbacks.
# 22/22 [==============================] - 9s 414ms/step - loss: 0.5107 - binary_crossentropy: 0.5107 - binary_accuracy: 0.8395 - val_loss: 0.4458 - val_binary_crossentropy: 0.4458 - val_binary_accuracy: 0.8521
# Epoch 2/25
# 22/22 [==============================] - 8s 365ms/step - loss: 0.4142 - binary_crossentropy: 0.4142 - binary_accuracy: 0.8721 - val_loss: 0.3816 - val_binary_crossentropy: 0.3816 - val_binary_accuracy: 0.9636
# Epoch 3/25
# 22/22 [==============================] - 8s 356ms/step - loss: 0.3554 - binary_crossentropy: 0.3554 - binary_accuracy: 0.9778 - val_loss: 0.3268 - val_binary_crossentropy: 0.3268 - val_binary_accuracy: 0.9883
# Epoch 4/25
# 22/22 [==============================] - 8s 364ms/step - loss: 0.3030 - binary_crossentropy: 0.3030 - binary_accuracy: 0.9908 - val_loss: 0.2777 - val_binary_crossentropy: 0.2777 - val_binary_accuracy: 0.9917
# Epoch 5/25
# 22/22 [==============================] - 8s 366ms/step - loss: 0.2516 - binary_crossentropy: 0.2516 - binary_accuracy: 0.9928 - val_loss: 0.2185 - val_binary_crossentropy: 0.2185 - val_binary_accuracy: 0.9928
# Epoch 6/25
# 22/22 [==============================] - 8s 368ms/step - loss: 0.1969 - binary_crossentropy: 0.1969 - binary_accuracy: 0.9936 - val_loss: 0.1741 - val_binary_crossentropy: 0.1741 - val_binary_accuracy: 0.9949
# Epoch 7/25
# 22/22 [==============================] - 8s 368ms/step - loss: 0.1560 - binary_crossentropy: 0.1560 - binary_accuracy: 0.9945 - val_loss: 0.1370 - val_binary_crossentropy: 0.1370 - val_binary_accuracy: 0.9946
# Epoch 8/25
# 22/22 [==============================] - 8s 368ms/step - loss: 0.1229 - binary_crossentropy: 0.1229 - binary_accuracy: 0.9950 - val_loss: 0.1073 - val_binary_crossentropy: 0.1073 - val_binary_accuracy: 0.9953
# Epoch 9/25
# 22/22 [==============================] - 7s 340ms/step - loss: 0.0938 - binary_crossentropy: 0.0938 - binary_accuracy: 0.9954 - val_loss: 0.0819 - val_binary_crossentropy: 0.0819 - val_binary_accuracy: 0.9950
# Epoch 10/25
# 22/22 [==============================] - 7s 335ms/step - loss: 0.0719 - binary_crossentropy: 0.0719 - binary_accuracy: 0.9958 - val_loss: 0.0621 - val_binary_crossentropy: 0.0621 - val_binary_accuracy: 0.9966
# Epoch 11/25
# 22/22 [==============================] - 8s 344ms/step - loss: 0.0560 - binary_crossentropy: 0.0560 - binary_accuracy: 0.9959 - val_loss: 0.0485 - val_binary_crossentropy: 0.0485 - val_binary_accuracy: 0.9963
# Epoch 12/25
# 22/22 [==============================] - 7s 341ms/step - loss: 0.0437 - binary_crossentropy: 0.0437 - binary_accuracy: 0.9961 - val_loss: 0.0379 - val_binary_crossentropy: 0.0379 - val_binary_accuracy: 0.9966
# Epoch 13/25
# 22/22 [==============================] - 7s 337ms/step - loss: 0.0345 - binary_crossentropy: 0.0345 - binary_accuracy: 0.9963 - val_loss: 0.0302 - val_binary_crossentropy: 0.0302 - val_binary_accuracy: 0.9966
# Epoch 14/25
# 22/22 [==============================] - 8s 370ms/step - loss: 0.0275 - binary_crossentropy: 0.0275 - binary_accuracy: 0.9966 - val_loss: 0.0242 - val_binary_crossentropy: 0.0242 - val_binary_accuracy: 0.9969
# Epoch 15/25
# 22/22 [==============================] - 8s 370ms/step - loss: 0.0222 - binary_crossentropy: 0.0222 - binary_accuracy: 0.9969 - val_loss: 0.0202 - val_binary_crossentropy: 0.0202 - val_binary_accuracy: 0.9970
# Epoch 16/25
# 22/22 [==============================] - 8s 370ms/step - loss: 0.0186 - binary_crossentropy: 0.0186 - binary_accuracy: 0.9970 - val_loss: 0.0170 - val_binary_crossentropy: 0.0170 - val_binary_accuracy: 0.9972
# Epoch 17/25
# 22/22 [==============================] - 8s 370ms/step - loss: 0.0154 - binary_crossentropy: 0.0154 - binary_accuracy: 0.9973 - val_loss: 0.0152 - val_binary_crossentropy: 0.0152 - val_binary_accuracy: 0.9972
# Epoch 18/25
# 22/22 [==============================] - 8s 363ms/step - loss: 0.0147 - binary_crossentropy: 0.0147 - binary_accuracy: 0.9970 - val_loss: 0.0132 - val_binary_crossentropy: 0.0132 - val_binary_accuracy: 0.9975
# Epoch 19/25
# 22/22 [==============================] - 8s 367ms/step - loss: 0.0125 - binary_crossentropy: 0.0125 - binary_accuracy: 0.9974 - val_loss: 0.0122 - val_binary_crossentropy: 0.0122 - val_binary_accuracy: 0.9975
# Epoch 20/25
# 22/22 [==============================] - 8s 369ms/step - loss: 0.0112 - binary_crossentropy: 0.0112 - binary_accuracy: 0.9976 - val_loss: 0.0120 - val_binary_crossentropy: 0.0120 - val_binary_accuracy: 0.9973
# Epoch 21/25
# 22/22 [==============================] - 8s 369ms/step - loss: 0.0112 - binary_crossentropy: 0.0112 - binary_accuracy: 0.9975 - val_loss: 0.0113 - val_binary_crossentropy: 0.0113 - val_binary_accuracy: 0.9976
# Epoch 22/25
# 22/22 [==============================] - 8s 372ms/step - loss: 0.0101 - binary_crossentropy: 0.0101 - binary_accuracy: 0.9977 - val_loss: 0.0116 - val_binary_crossentropy: 0.0116 - val_binary_accuracy: 0.9973
# Epoch 23/25
# 22/22 [==============================] - 8s 373ms/step - loss: 0.0105 - binary_crossentropy: 0.0105 - binary_accuracy: 0.9975 - val_loss: 0.0108 - val_binary_crossentropy: 0.0108 - val_binary_accuracy: 0.9977
# Epoch 24/25
# 22/22 [==============================] - 8s 373ms/step - loss: 0.0095 - binary_crossentropy: 0.0095 - binary_accuracy: 0.9978 - val_loss: 0.0117 - val_binary_crossentropy: 0.0117 - val_binary_accuracy: 0.9972
# Epoch 25/25
# 22/22 [==============================] - 8s 374ms/step - loss: 0.0094 - binary_crossentropy: 0.0094 - binary_accuracy: 0.9978 - val_loss: 0.0120 - val_binary_crossentropy: 0.0120 - val_binary_accuracy: 0.9970

# %%
prediction = circle_model.net.predict(test_ds.batch(batch_size=32))

# %%
N = 5
fig, ax = plt.subplots(3, N, sharex=True, sharey=True,
                       figsize=(N * 3, 9), gridspec_kw={'wspace': 0.01, 'hspace': 0.015})
dataset = test_ds.map(crop_image_labels_to_shape(prediction.shape[1:]) )

for i, (img, label) in enumerate(dataset.take(N)):
    ax[0][i].imshow(tf.keras.preprocessing.image.array_to_img(img))
    ax[1][i].imshow(np.argmax(label, axis=-1), cmap=plt.cm.gray)
    ax[2][i].imshow(np.argmax(prediction[i, ...], axis=-1), cmap=plt.cm.gray)
for i, x in enumerate(['image', 'mask', 'prediction']):
    ax[i][0].set_ylabel(x);

# %%
def show_history(history, EPOCHS=25):
  train_loss = history.history['loss']
  val_loss = history.history['val_loss']
  train_acc = history.history['binary_accuracy']
  val_acc = history.history['val_binary_accuracy']

  fig, axes = plt.subplots(1, 2, figsize=(14, 5))
  axes[0].plot(range(EPOCHS), train_loss, 'r--', label='training loss')
  axes[0].plot(range(EPOCHS), val_loss, 'bo', label='validation loss')
  axes[0].set_title('Training and validation loss')
  axes[0].set_xlabel('Epoch')
  axes[0].set_ylabel('Loss')
  axes[0].legend()

  axes[1].plot(range(EPOCHS), train_acc, 'r--', label='training accuracy')
  axes[1].plot(range(EPOCHS), val_acc, 'bo', label='validation accuracy')
  axes[1].set_title('Training and validation accuracy')
  axes[1].set_xlabel('Epoch')
  axes[1].set_ylabel('Accuracy')
  axes[1].legend()

# %%
show_history(history)
